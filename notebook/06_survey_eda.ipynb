# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (8,5)

# %%
df = pd.read_csv("../data/processed/survey_cleaned.csv")

# %%
df.head()
# Out:
#   age_group occupation  gender smartphone_type        screen_time  \
# 0     18–24    Student    Male         Android          4–6 hours
# 1     18–24    Student    Male             iOS          4–6 hours
# 2     18–24    Student    Male             iOS  More than 6 hours
# 3     18–24    Student    Male         Android          4–6 hours
# 4  Below 18    Student  Female             iOS          2–4 hours
#
#                                 daily_app_categories  \
# 0  Social Media, Video / OTT, Gaming, Shopping / ...
# 1               Social Media, Video / OTT, Education
# 2                  Social Media, Video / OTT, Gaming
# 3  Social Media, Video / OTT, Shopping / E-commer...
# 4   Social Media, Video / OTT, Shopping / E-commerce
#
#                                  most_used_category ad_frequency  \
# 0                 Social Media, Video / OTT, Gaming        Often
# 1              Social Media, Video / OTT, Education        Often
# ...

# %%
df.shape
# Out:
# (411, 23)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age_group                    410 non-null    str
#  1   occupation                   410 non-null    str
#  2   gender                       410 non-null    str
#  3   smartphone_type              408 non-null    str
#  4   screen_time                  410 non-null    str
#  5   daily_app_categories         391 non-null    str
#  6   most_used_category           385 non-null    str
#  7   ad_frequency                 410 non-null    str
#  8   frequent_ad_format           409 non-null    str
#  9   most_excessive_ad_category   410 non-null    str
#  10  ads_interrupt_usage          410 non-null    str
#  11  ads_cause_frustration        410 non-null    str
#  12  ads_reduce_enjoyment         410 non-null    str
#  13  ads_close_app                410 non-null    str
# ...

# %%
df.describe(include="all")
# Out:
#        age_group occupation gender smartphone_type screen_time  \
# count        410        410    410             408         410
# unique         5          4      3               2           4
# top        18–24    Student   Male         Android   4–6 hours
# freq         142        149    195             258         114
# mean         NaN        NaN    NaN             NaN         NaN
# std          NaN        NaN    NaN             NaN         NaN
# min          NaN        NaN    NaN             NaN         NaN
# 25%          NaN        NaN    NaN             NaN         NaN
# 50%          NaN        NaN    NaN             NaN         NaN
# 75%          NaN        NaN    NaN             NaN         NaN
# max          NaN        NaN    NaN             NaN         NaN
#
#                                     daily_app_categories  \
# count                                                391
# unique                                               113
# ...

# %%
plt.figure()
df['age_group'].value_counts().plot(kind='bar')
plt.title("Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of Users")
plt.show()

# %%
plt.figure()
df['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure()
df['occupation'].value_counts().plot(kind='bar')
plt.title("Occupation Distribution")
plt.xlabel("Occupation")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
df['smartphone_type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Smartphone Type Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure()
sns.histplot(df['screen_time'], bins=10)
plt.title("Daily Screen Time Distribution")
plt.xlabel("Screen Time")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.boxplot(x='age_group', y='screen_time', data=df)
plt.title("Age Group vs Screen Time")
plt.show()

# %%
plt.figure()
sns.boxplot(x='occupation', y='screen_time', data=df)
plt.xticks(rotation=45)
plt.title("Occupation vs Screen Time")
plt.show()

# %%
plt.figure()
sns.boxplot(x='gender', y='screen_time', data=df)
plt.title("Gender vs Screen Time")
plt.show()

# %%
cross = pd.crosstab(df['age_group'], df['smartphone_type'])

cross.plot(kind='bar', stacked=True)
plt.title("Age Group vs Smartphone Type")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.countplot(x='occupation', hue='smartphone_type', data=df)
plt.xticks(rotation=45)
plt.title("Occupation vs Smartphone Type")
plt.show()

# %%
plt.figure()
sns.countplot(x='age_group', hue='ad_frequency', data=df)
plt.title("Age Group vs Advertisement Frequency")
plt.xlabel("Age Group")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
sns.countplot(x='gender', hue='ads_cause_frustration', data=df)
plt.title("Gender vs Ad Frustration")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.countplot(x='gender', hue='ads_cause_frustration', data=df)
plt.title("Gender vs Ad Frustration")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.countplot(x='occupation', hue='most_annoying_ad_time', data=df)
plt.title("Occupation vs Most Annoying Ad Timing")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
sns.boxplot(x='age_group', y='ad_fatigue_index', data=df)
plt.title("Age Group vs Ad Fatigue Index")
plt.xlabel("Age Group")
plt.ylabel("Ad Fatigue Index")
plt.xticks(rotation=45)
plt.show()

# %%
sns.heatmap(
pd.crosstab(df["screen_time"], df["ads_cause_frustration"]),
annot=True,
fmt="d",
cmap="Blues"
)

plt.title("Screen Time vs Advertisement Frustration")

plt.show()

# %%
sns.heatmap(
pd.crosstab(df["age_group"], df["pay_for_adfree"]),
annot=True,
fmt="d",
cmap="Greens"
)

plt.title("Age vs Willingness to Pay for Ad-Free Apps")

plt.show()

# %%
print("""The exploratory analysis of the survey dataset provides insights into smartphone usage patterns and user behavior. The data indicates that smartphones play a significant role in daily life, with many users spending considerable time on mobile applications for communication, entertainment, and information access. Certain applications appear to be used more frequently than others, suggesting strong user preference toward social media, messaging, and video platforms. The variation in screen time among respondents shows that digital engagement levels differ from person to person. Some users demonstrate moderate usage while others spend extended periods on their devices. The dataset also reflects a diverse group of participants, which helps in understanding different user habits and preferences. Overall, the analysis highlights how mobile devices and applications have become an integral part of modern lifestyles and how user engagement on these platforms can influence digital marketing and targeted advertising strategies.""")
# Out:
# The exploratory analysis of the survey dataset provides insights into smartphone usage patterns and user behavior. The data indicates that smartphones play a significant role in daily life, with many users spending considerable time on mobile applications for communication, entertainment, and information access. Certain applications appear to be used more frequently than others, suggesting strong user preference toward social media, messaging, and video platforms. The variation in screen time among respondents shows that digital engagement levels differ from person to person. Some users demonstrate moderate usage while others spend extended periods on their devices. The dataset also reflects a diverse group of participants, which helps in understanding different user habits and preferences. Overall, the analysis highlights how mobile devices and applications have become an integral part of modern lifestyles and how user engagement on these platforms can influence digital marketing an
# ...

# %%
plt.figure()
order = ['Rarely', 'Sometimes', 'Often', 'Always']
order = [x for x in order if x in df['ad_frequency'].unique()]
if not order: order = df['ad_frequency'].value_counts().index
sns.countplot(data=df, x='ad_frequency', order=order, palette='viridis')
plt.title("Advertisement Frequency Distribution")
plt.xlabel("Ad Frequency")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
order = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']
actual_order = [x for x in order if x in df['ads_interrupt_usage'].unique()]
sns.countplot(data=df, x='ads_interrupt_usage', order=actual_order, palette='coolwarm')
plt.title("Ads Interrupt Usage")
plt.xlabel("Response")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
actual_order = [x for x in order if x in df['ads_cause_frustration'].unique()]
sns.countplot(data=df, x='ads_cause_frustration', order=actual_order, palette='coolwarm')
plt.title("Ads Cause Frustration")
plt.xlabel("Frustration Level")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
actual_order = [x for x in order if x in df['ads_reduce_enjoyment'].unique()]
sns.countplot(data=df, x='ads_reduce_enjoyment', order=actual_order, palette='coolwarm')
plt.title("Ads Reduce Enjoyment")
plt.xlabel("Impact on Enjoyment")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 20. Ads Close the App
# Bar chart showing how often users exit apps due to ads.

# %%
plt.figure()
actual_order = [x for x in order if x in df['ads_close_app'].unique()]
sns.countplot(data=df, x='ads_close_app', order=actual_order, palette='coolwarm')
plt.title("Ads Cause Users to Close the App")
plt.xlabel("Response")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 21. Most Annoying Ad Timing
# Bar chart identifying when ads are most irritating.

# %%
plt.figure()
sns.countplot(data=df, x='most_annoying_ad_time', palette='magma', order=df['most_annoying_ad_time'].value_counts().index)
plt.title("Most Annoying Ad Timing")
plt.xlabel("Time of Day")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 22. Preferred Ad Format
# Pie chart showing preferred (tolerated) advertisement formats.

# %%
plt.figure(figsize=(8, 8))
format_counts = df['tolerated_ad_format'].value_counts()
plt.pie(format_counts, labels=format_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title("Preferred / Tolerated Ad Format")
plt.show()

# %% [markdown]
# ### 23. Tolerated Ad Format
# Bar chart showing acceptable ad formats.

# %%
plt.figure()
sns.countplot(data=df, y='tolerated_ad_format', palette='Set2', order=df['tolerated_ad_format'].value_counts().index)
plt.title("Tolerated Ad Formats")
plt.xlabel("Number of Users")
plt.ylabel("Ad Format")
plt.show()

# %% [markdown]
# ### 24. Ad Frequency vs Frustration
# Box plot showing relationship between ad exposure and frustration.

# %%
plt.figure()
freq_order = ['Rarely', 'Sometimes', 'Often', 'Always']
freq_order = [x for x in freq_order if x in df['ad_frequency'].unique()]
sns.boxplot(data=df, x='ad_frequency', y='ads_cause_frustration_score', palette='Set3', order=freq_order)
plt.title("Ad Frequency vs Frustration Score")
plt.xlabel("Ad Frequency")
plt.ylabel("Frustration Score (1-5)")
plt.show()

# %% [markdown]
# ### 25. Age Group vs Ad Frustration
# Stacked bar chart analyzing frustration across age groups.

# %%
crosstab_data = pd.crosstab(df['age_group'], df['ads_cause_frustration'])
col_order = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']
actual_col_order = [x for x in col_order if x in crosstab_data.columns]
crosstab_data = crosstab_data.reindex(columns=actual_col_order)
crosstab_data.plot(kind='bar', stacked=True, colormap='coolwarm', figsize=(10, 6))
plt.title("Age Group vs Ad Frustration")
plt.xlabel("Age Group")
plt.ylabel("Number of Users")
plt.xticks(rotation=45)
plt.legend(title='Frustration Level', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 26. Screen Time vs Ad Frustration
# Scatter plot to identify correlation.

# %%
plt.figure()
sns.stripplot(data=df, x='screen_time', y='ads_cause_frustration_score', jitter=True, alpha=0.5, palette='Dark2')
plt.title("Screen Time vs Ad Frustration Score")
plt.xlabel("Screen Time")
plt.ylabel("Frustration Score (1-5)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 27. Occupation vs Ad Fatigue
# Box plot analyzing fatigue levels by occupation.

# %%
plt.figure()
sns.boxplot(data=df, x='occupation', y='ad_fatigue_index', palette='Set1')
plt.title("Occupation vs Ad Fatigue Index")
plt.xlabel("Occupation")
plt.ylabel("Ad Fatigue Index")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
sns.histplot(data=df, x='ad_fatigue_index', bins=15, kde=True, color='purple')
plt.title("Ad Fatigue Index Distribution")
plt.xlabel("Ad Fatigue Index")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 29. Age Group vs Ad Fatigue Index
# Box plot showing fatigue by age group.

# %%
plt.figure()
sns.boxplot(data=df, x='age_group', y='ad_fatigue_index', palette='muted')
plt.title("Age Group vs Ad Fatigue Index")
plt.xlabel("Age Group")
plt.ylabel("Ad Fatigue Index")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 30. Screen Time vs Ad Fatigue Index
# Scatter plot analyzing fatigue vs usage time.

# %%
plt.figure()
sns.stripplot(data=df, x='screen_time', y='ad_fatigue_index', jitter=True, alpha=0.6, palette='Set2')
plt.title("Screen Time vs Ad Fatigue Index")
plt.xlabel("Screen Time")
plt.ylabel("Ad Fatigue Index")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Business Insight
# This section helps companies understand which users are most affected by advertisements and how ad exposure impacts user experience, enabling better ad frequency control and format optimization.
