# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../data/processed/survey_cleaned.csv")

# %%
features = df[['ads_interrupt_usage_score',
               'ads_cause_frustration_score',
               'ads_reduce_enjoyment_score',
               'ads_close_app_score',
               'ad_fatigue_index']]

# %%
features = features.fillna(features.mean())

# %%
features = features.dropna()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

df['Cluster'] = kmeans.fit_predict(X_scaled)

df.head()
# Out:
#   age_group occupation  gender smartphone_type        screen_time  \
# 0     18–24    Student    Male         Android          4–6 hours
# 1     18–24    Student    Male             iOS          4–6 hours
# 2     18–24    Student    Male             iOS  More than 6 hours
# 3     18–24    Student    Male         Android          4–6 hours
# 4  Below 18    Student  Female             iOS          2–4 hours
#
#                                 daily_app_categories  \
# 0  Social Media, Video / OTT, Gaming, Shopping / ...
# 1               Social Media, Video / OTT, Education
# 2                  Social Media, Video / OTT, Gaming
# 3  Social Media, Video / OTT, Shopping / E-commer...
# 4   Social Media, Video / OTT, Shopping / E-commerce
#
#                                  most_used_category ad_frequency  \
# 0                 Social Media, Video / OTT, Gaming        Often
# 1              Social Media, Video / OTT, Education        Often
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

features = df[['ads_interrupt_usage_score',
               'ads_cause_frustration_score',
               'ads_reduce_enjoyment_score',
               'ads_close_app_score',
               'ad_fatigue_index']]

features = features.fillna(features.mean())

scaler = StandardScaler()
X = scaler.fit_transform(features)

kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Select features
features = df[['ads_interrupt_usage_score',
               'ads_cause_frustration_score',
               'ads_reduce_enjoyment_score',
               'ads_close_app_score',
               'ad_fatigue_index']]

features = features.fillna(features.mean())

# Scale
scaler = StandardScaler()
X = scaler.fit_transform(features)

# KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X)

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot
plt.figure(figsize=(6,5))

plt.scatter(X_pca[:,0], X_pca[:,1],
            c=clusters,
            cmap='viridis',
            s=70)

centers = pca.transform(kmeans.cluster_centers_)

plt.scatter(centers[:,0], centers[:,1],
            c='black',
            s=200,
            marker='X')

plt.title("User Clusters based on Advertisement Behaviour")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %%
features2 = df[['ads_interrupt_usage_score',
                'ads_close_app_score',
                'ad_fatigue_index']]

features2 = features2.fillna(features2.mean())

scaler = StandardScaler()
X2 = scaler.fit_transform(features2)

kmeans2 = KMeans(n_clusters=3, random_state=42)
clusters2 = kmeans2.fit_predict(X2)

pca2 = PCA(n_components=2)
X2_pca = pca2.fit_transform(X2)

plt.figure(figsize=(6,5))

plt.scatter(X2_pca[:,0], X2_pca[:,1],
            c=clusters2,
            cmap='plasma',
            s=70)

centers2 = pca2.transform(kmeans2.cluster_centers_)

plt.scatter(centers2[:,0], centers2[:,1],
            c='black',
            s=200,
            marker='X')

plt.title("Clusters based on Advertisement Fatigue")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()
