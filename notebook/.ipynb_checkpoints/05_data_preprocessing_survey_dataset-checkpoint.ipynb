# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/survey/survey_dataset.csv")

# %%
df.head()
# Out:
#              Timestamp Age Group? Occupation?  Gender  \
# 0  05/02/2026 20:55:23      18–24     Student    Male
# 1  05/02/2026 20:56:07      18–24     Student    Male
# 2  05/02/2026 20:56:19      18–24     Student    Male
# 3  05/02/2026 20:56:51      18–24     Student    Male
# 4  05/02/2026 20:57:04   Below 18     Student  Female
#
#   What type of smartphone do you primarily use?  \
# 0                                       Android
# 1                                           iOS
# 2                                           iOS
# 3                                       Android
# 4                                           iOS
#
#   Average daily mobile screen time?   \
# 0                          4–6 hours
# 1                          4–6 hours
# 2                  More than 6 hours
# 3                          4–6 hours
# 4                          2–4 hours
#
#               Which app categories do you use daily?  \
# 0  Social Media, Video / OTT, Gaming, Shopping / ...
# 1               Social Media, Video / OTT, Education
# 2                  Social Media, Video / OTT, Gaming
# 3  Social Media, Video / OTT, Shopping / E-commer...
# 4   Social Media, Video / OTT, Shopping / E-commerce
#
#       Which category do you spend the MOST time on?  \
# 0                 Social Media, Video / OTT, Gaming
# 1              Social Media, Video / OTT, Education
# 2                 Social Media, Video / OTT, Gaming
# 3    Social Media, Shopping / E-commerce, Education
# 4  Social Media, Video / OTT, Shopping / E-commerce
#
#   How often do you see ads while using mobile apps?  \
# 0                                             Often
# 1                                             Often
# 2                                         Sometimes
# 3                                         Sometimes
# 4                                         Sometimes
#
#   Which ad formats do you encounter most frequently?  \
# 0                                    Unskippable ads
# 1                                          Video ads
# 2                                    Sponsored posts
# 3                                          Video ads
# 4                                         Banner ads
#
#   In which app category do you feel ads are MOST excessive?  \
# 0                                             Gaming
# 1                                        Video / OTT
# 2                                       Social Media
# 3                                       Social Media
# 4                                        Video / OTT
#
#   Fill the following [Ads interrupt my app usage experience]  \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                            Neutral
# 4                                            Neutral
#
#   Fill the following [I feel frustrated due to frequent advertisements]  \
# 0                                     Strongly agree
# 1                                     Strongly agree
# 2                                     Strongly agree
# 3                                              Agree
# 4                                            Neutral
#
#   Fill the following [Ads reduce my enjoyment while using apps]  \
# 0                                     Strongly agree
# 1                                              Agree
# 2                                     Strongly agree
# 3                                              Agree
# 4                                              Agree
#
#   Fill the following [Ads have caused me to close an app or stop using it temporarily]  \
# 0                                            Neutral
# 1                                              Agree
# 2                                           Disagree
# 3                                            Neutral
# 4                                           Disagree
#
#   Ads have made me uninstall an app in the past  \
# 0                                           Yes
# 1                                           Yes
# 2                                            No
# 3                                           Yes
# 4                                            No
#
#   Which ad format do you tolerate the MOST?  \
# 0                       Skippable video ads
# 1                       Skippable video ads
# 2                       Skippable video ads
# 3                              Rewarded ads
# 4                                Banner ads
#
#   Which time do you find ads MOST annoying?  \
# 0                                   Evening
# 1                                   Evening
# 2                                   Evening
# 3                                       NaN
# 4                                   Morning
#
#   Would you pay for an ad-free version of an app you use frequently?
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                 No

# %%
df.shape
# Out:
# (420, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 19 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Timestamp                                                                             420 non-null    object
#  1   Age Group?                                                                            414 non-null    object
#  2   Occupation?                                                                           414 non-null    object
#  3   Gender                                                                                414 non-null    object
#  4   What type of smartphone do you primarily use?                                         412 non-null    object
#  5   Average daily mobile screen time?                                                     414 non-null    object
#  6   Which app categories do you use daily?                                                395 non-null    object
#  7   Which category do you spend the MOST time on?                                         389 non-null    object
#  8   How often do you see ads while using mobile apps?                                     414 non-null    object
#  9   Which ad formats do you encounter most frequently?                                    413 non-null    object
#  10  In which app category do you feel ads are MOST excessive?                             414 non-null    object
#  11  Fill the following [Ads interrupt my app usage experience]                            414 non-null    object
#  12  Fill the following [I feel frustrated due to frequent advertisements]                 414 non-null    object
#  13  Fill the following [Ads reduce my enjoyment while using apps]                         414 non-null    object
#  14  Fill the following [Ads have caused me to close an app or stop using it temporarily]  414 non-null    object
#  15  Ads have made me uninstall an app in the past                                         414 non-null    object
#  16  Which ad format do you tolerate the MOST?                                             353 non-null    object
#  17  Which time do you find ads MOST annoying?                                             406 non-null    object
#  18  Would you pay for an ad-free version of an app you use frequently?                    414 non-null    object
# dtypes: object(19)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                0
# Age Group?                                                                               6
# Occupation?                                                                              6
# Gender                                                                                   6
# What type of smartphone do you primarily use?                                            8
# Average daily mobile screen time?                                                        6
# Which app categories do you use daily?                                                  25
# Which category do you spend the MOST time on?                                           31
# How often do you see ads while using mobile apps?                                        6
# Which ad formats do you encounter most frequently?                                       7
# In which app category do you feel ads are MOST excessive?                                6
# Fill the following [Ads interrupt my app usage experience]                               6
# Fill the following [I feel frustrated due to frequent advertisements]                    6
# Fill the following [Ads reduce my enjoyment while using apps]                            6
# Fill the following [Ads have caused me to close an app or stop using it temporarily]     6
# Ads have made me uninstall an app in the past                                            6
# Which ad format do you tolerate the MOST?                                               67
# Which time do you find ads MOST annoying?                                               14
# Would you pay for an ad-free version of an app you use frequently?                       6
# dtype: int64

# %%
df.columns = [
"timestamp",
"age_group",
"occupation",
"gender",
"smartphone_type",
"screen_time",
"daily_app_categories",
"most_used_category",
"ad_frequency",
"frequent_ad_format",
"most_excessive_ad_category",
"ads_interrupt_usage",
"ads_cause_frustration",
"ads_reduce_enjoyment",
"ads_close_app",
"ads_uninstall_app",
"tolerated_ad_format",
"most_annoying_ad_time",
"pay_for_adfree"
]

# %%
df.columns
# Out:
# Index(['timestamp', 'age_group', 'occupation', 'gender', 'smartphone_type',
#        'screen_time', 'daily_app_categories', 'most_used_category',
#        'ad_frequency', 'frequent_ad_format', 'most_excessive_ad_category',
#        'ads_interrupt_usage', 'ads_cause_frustration', 'ads_reduce_enjoyment',
#        'ads_close_app', 'ads_uninstall_app', 'tolerated_ad_format',
#        'most_annoying_ad_time', 'pay_for_adfree'],
#       dtype='object')

# %%
df = df.drop(columns=["timestamp"])

# %%
df.isnull().sum()
# Out:
# age_group                      6
# occupation                     6
# gender                         6
# smartphone_type                8
# screen_time                    6
# daily_app_categories          25
# most_used_category            31
# ad_frequency                   6
# frequent_ad_format             7
# most_excessive_ad_category     6
# ads_interrupt_usage            6
# ads_cause_frustration          6
# ads_reduce_enjoyment           6
# ads_close_app                  6
# ads_uninstall_app              6
# tolerated_ad_format           67
# most_annoying_ad_time         14
# pay_for_adfree                 6
# dtype: int64

# %%
demographic_cols = [
"age_group",
"occupation",
"gender",
"smartphone_type",
"screen_time"
]

for col in demographic_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /var/folders/z7/4zbkkbkd4xzc1m0hkwzwjck00000gn/T/ipykernel_86083/2225661814.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
usage_cols = [
"daily_app_categories",
"most_used_category"
]

for col in usage_cols:
    df[col].fillna("Unknown", inplace=True)
# Out:
# /var/folders/z7/4zbkkbkd4xzc1m0hkwzwjck00000gn/T/ipykernel_86083/2218257611.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)

# %%
ads_cols = [
"ad_frequency",
"frequent_ad_format",
"most_excessive_ad_category",
"ads_interrupt_usage",
"ads_cause_frustration",
"ads_reduce_enjoyment",
"ads_close_app",
"ads_uninstall_app",
"pay_for_adfree"
]

for col in ads_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /var/folders/z7/4zbkkbkd4xzc1m0hkwzwjck00000gn/T/ipykernel_86083/397244981.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df["tolerated_ad_format"].fillna("None / Not Sure", inplace=True)
# Out:
# /var/folders/z7/4zbkkbkd4xzc1m0hkwzwjck00000gn/T/ipykernel_86083/939742511.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["tolerated_ad_format"].fillna("None / Not Sure", inplace=True)

# %%
df["most_annoying_ad_time"].fillna("Unknown", inplace=True)
# Out:
# /var/folders/z7/4zbkkbkd4xzc1m0hkwzwjck00000gn/T/ipykernel_86083/4107467715.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["most_annoying_ad_time"].fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# age_group                     0
# occupation                    0
# gender                        0
# smartphone_type               0
# screen_time                   0
# daily_app_categories          0
# most_used_category            0
# ad_frequency                  0
# frequent_ad_format            0
# most_excessive_ad_category    0
# ads_interrupt_usage           0
# ads_cause_frustration         0
# ads_reduce_enjoyment          0
# ads_close_app                 0
# ads_uninstall_app             0
# tolerated_ad_format           0
# most_annoying_ad_time         0
# pay_for_adfree                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.convert_dtypes()

# %%
mapping = {
"Strongly disagree":1,
"Disagree":2,
"Neutral":3,
"Agree":4,
"Strongly agree":5
}

fatigue_cols = [
"ads_interrupt_usage",
"ads_cause_frustration",
"ads_reduce_enjoyment",
"ads_close_app"
]

for col in fatigue_cols:
    df[col+"_score"] = df[col].map(mapping)

df["ad_fatigue_index"] = df[[c+"_score" for c in fatigue_cols]].mean(axis=1)

# %%
df.head()
# Out:
#   age_group occupation  gender smartphone_type        screen_time  \
# 0     18–24    Student    Male         Android          4–6 hours
# 1     18–24    Student    Male             iOS          4–6 hours
# 2     18–24    Student    Male             iOS  More than 6 hours
# 3     18–24    Student    Male         Android          4–6 hours
# 4  Below 18    Student  Female             iOS          2–4 hours
#
#                                 daily_app_categories  \
# 0  Social Media, Video / OTT, Gaming, Shopping / ...
# 1               Social Media, Video / OTT, Education
# 2                  Social Media, Video / OTT, Gaming
# 3  Social Media, Video / OTT, Shopping / E-commer...
# 4   Social Media, Video / OTT, Shopping / E-commerce
#
#                                  most_used_category ad_frequency  \
# 0                 Social Media, Video / OTT, Gaming        Often
# 1              Social Media, Video / OTT, Education        Often
# 2                 Social Media, Video / OTT, Gaming    Sometimes
# 3    Social Media, Shopping / E-commerce, Education    Sometimes
# 4  Social Media, Video / OTT, Shopping / E-commerce    Sometimes
#
#   frequent_ad_format most_excessive_ad_category  ... ads_close_app  \
# 0    Unskippable ads                     Gaming  ...       Neutral
# 1          Video ads                Video / OTT  ...         Agree
# 2    Sponsored posts               Social Media  ...      Disagree
# 3          Video ads               Social Media  ...       Neutral
# 4         Banner ads                Video / OTT  ...      Disagree
#
#   ads_uninstall_app  tolerated_ad_format most_annoying_ad_time pay_for_adfree  \
# 0               Yes  Skippable video ads               Evening             No
# 1               Yes  Skippable video ads               Evening            Yes
# 2                No  Skippable video ads               Evening            Yes
# 3               Yes         Rewarded ads               Unknown            Yes
# 4                No           Banner ads               Morning             No
#
#   ads_interrupt_usage_score ads_cause_frustration_score  \
# 0                         4                           5
# 1                         5                           5
# 2                         4                           5
# 3                         3                           4
# 4                         3                           3
#
#   ads_reduce_enjoyment_score  ads_close_app_score  ad_fatigue_index
# 0                          5                    3              4.25
# 1                          4                    4              4.50
# 2                          5                    2              4.00
# 3                          4                    3              3.50
# 4                          4                    2              3.00
#
# [5 rows x 23 columns]

# %%
df.describe(include="all")
# Out:
#        age_group occupation gender smartphone_type screen_time  \
# count        411        411    411             411         411
# unique         5          4      3               2           4
# top        18–24    Student   Male         Android   4–6 hours
# freq         143        150    196             261         115
# mean         NaN        NaN    NaN             NaN         NaN
# std          NaN        NaN    NaN             NaN         NaN
# min          NaN        NaN    NaN             NaN         NaN
# 25%          NaN        NaN    NaN             NaN         NaN
# 50%          NaN        NaN    NaN             NaN         NaN
# 75%          NaN        NaN    NaN             NaN         NaN
# max          NaN        NaN    NaN             NaN         NaN
#
#        daily_app_categories                 most_used_category ad_frequency  \
# count                   411                                411          411
# unique                  114                                106            4
# top                 Unknown  Social Media, Video / OTT, Gaming        Often
# freq                     20                                 33          122
# mean                    NaN                                NaN          NaN
# std                     NaN                                NaN          NaN
# min                     NaN                                NaN          NaN
# 25%                     NaN                                NaN          NaN
# 50%                     NaN                                NaN          NaN
# 75%                     NaN                                NaN          NaN
# max                     NaN                                NaN          NaN
#
#        frequent_ad_format most_excessive_ad_category  ...   ads_close_app  \
# count                 411                        411  ...             411
# unique                  5                          7  ...               5
# top             Video ads                Video / OTT  ...  Strongly agree
# freq                  108                         88  ...             103
# mean                  NaN                        NaN  ...             NaN
# std                   NaN                        NaN  ...             NaN
# min                   NaN                        NaN  ...             NaN
# 25%                   NaN                        NaN  ...             NaN
# 50%                   NaN                        NaN  ...             NaN
# 75%                   NaN                        NaN  ...             NaN
# max                   NaN                        NaN  ...             NaN
#
#        ads_uninstall_app  tolerated_ad_format most_annoying_ad_time  \
# count                411                  411                   411
# unique                 2                    5                     5
# top                   No  Skippable video ads            Late night
# freq                 216                  112                   118
# mean                 NaN                  NaN                   NaN
# std                  NaN                  NaN                   NaN
# min                  NaN                  NaN                   NaN
# 25%                  NaN                  NaN                   NaN
# 50%                  NaN                  NaN                   NaN
# 75%                  NaN                  NaN                   NaN
# max                  NaN                  NaN                   NaN
#
#        pay_for_adfree ads_interrupt_usage_score ads_cause_frustration_score  \
# count             411                411.000000                  411.000000
# unique              2                       NaN                         NaN
# top                No                       NaN                         NaN
# freq              235                       NaN                         NaN
# mean              NaN                  3.223844                    3.243309
# std               NaN                  1.387581                    1.410474
# min               NaN                  1.000000                    1.000000
# 25%               NaN                  2.000000                    2.000000
# 50%               NaN                  3.000000                    3.000000
# 75%               NaN                  4.000000                    4.000000
# max               NaN                  5.000000                    5.000000
#
#        ads_reduce_enjoyment_score  ads_close_app_score  ad_fatigue_index
# count                  411.000000           411.000000        411.000000
# unique                        NaN                  NaN               NaN
# top                           NaN                  NaN               NaN
# freq                          NaN                  NaN               NaN
# mean                     3.328467             3.248175          3.260949
# std                      1.397434             1.390461          0.926179
# min                      1.000000             1.000000          1.000000
# 25%                      2.000000             2.000000          2.500000
# 50%                      4.000000             3.000000          3.250000
# 75%                      5.000000             4.500000          4.000000
# max                      5.000000             5.000000          5.000000
#
# [11 rows x 23 columns]

# %%
df.to_csv("../data/processed/survey_cleaned.csv", index=False)

# %%
df.to_csv("../dashboard/dashboard_dataset_survey.csv", index=False)
